# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeWith-Sana/Learn-ML-WithSana/blob/main/Lists_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # List are created wit square brackets with comma separated every element
# # Lists are more flexibles than arrays because it can store
# # different types.

# %%
first_list=[1,2,3]

# %%
first_list
# Out:
# [1, 2, 3]

# %%
type(first_list)
# Out:
# list

# %%
second_list = [7, 'Hello', 4.5]

# %%
second_list
# Out:
# [7, 'Hello', 4.5]

# %%
len(second_list)
# Out:
# 3

# %% [markdown]
# # Indexing and Slicing

# %%
list=['one','two',3,4,'hello',7.2]

# %%
list[0]
# Out:
# 'one'

# %%
list[-1]
# Out:
# 7.2

# %%
list[1:5]
# Out:
# ['two', 3, 4, 'hello']

# %%
list[:-1]
# Out:
# ['one', 'two', 3, 4, 'hello']

# %% [markdown]
# # Adding element to the list

# %%
list=['one','two',3, 4,'hello', 7.2]

# %%
list = list + ['world']

# %%
list
# Out:
# ['one', 'two', 3, 4, 'hello', 7.2, 'world']

# %% [markdown]
# # Adding and replacing elements inside the list

# %%
list=['one','two',3, 4,'hello', 7.2]

# %%
list[2] = 2

# %%
list
# Out:
# ['one', 'two', 2, 4, 'hello', 7.2]

# %%
list[2:4]=[10,11]

# %%
list
# Out:
# ['one', 'two', 10, 11, 'hello', 7.2]

# %% [markdown]
# # Methods on list

# %%
list =[1,2,3]

# %%
list.append(5) # append will add the value to the end of the list

# %%
list
# Out:
# [1, 2, 3, 5]

# %%
list.pop() # remove the last element
# Out:
# 5

# %%
list
# Out:
# [1, 2, 3]

# %%
list.pop(1) # remove the element at index 1
# Out:
# 2

# %%
new_list=['a','e','x','b','c']

# %%
new_list.reverse()

# %%
new_list
# Out:
# ['c', 'b', 'x', 'e', 'a']

# %%
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %% [markdown]
# # Nested list

# %%
my_list = [1,2,3,4]

# %%
my_list = [1,2,3,4,[6,7,8]]

# %%
my_list
# Out:
# [1, 2, 3, 4, [6, 7, 8]]

# %% [markdown]
# ### Other Method

# %%
# Let's make three lists
list_1 = [1,2,3]
list_2 = [4,5,6]
list_3 = [7,8,9]

# Make a list of lists to form a matrix
matrix = [list_1, list_2, list_3]

# %%
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# ### Nested list with append

# %%
new_list = [1,2,3,4]

# %%
new_list.append([11,12,13])

# %%
new_list
# Out:
# [1, 2, 3, 4, [11, 12, 13]]

# %% [markdown]
# ### Indexing in Nested list

# %%
new_list
# Out:
# [1, 2, 3, 4, [11, 12, 13]]

# %%
new_list[4]
# Out:
# [11, 12, 13]

# %%
new_list[4][0]
# Out:
# 11

# %%
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix[0]
# Out:
# [1, 2, 3]

# %%
matrix[0][0]
# Out:
# 1

# %% [markdown]
# #### Extracting 7 from matrix

# %%
matrix[2][0]
# Out:
# 7
